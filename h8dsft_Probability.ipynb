# %%
# %matplotlib inline
import random

head_tails = [0, 0]

trials = 50000
trial = 0
while trial < trials:
    trial = trial + 1
    toss = random.randint(0, 1)
    head_tails[toss] = heads_tails[toss] + 1

print(head_tails)


from matplotlib import pyplot as plt
plt.figure(figsize=(5, 5))
plt.pie(head_tails, labels=['heads', 'tails'])
plt.legend()
plt.show()
# Out:
# [1, 1]
